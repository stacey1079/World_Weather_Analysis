# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 770

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Current Description": city_description
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cabo san lucas
# Processing Record 2 of Set 1 | lorengau
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | shingu
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | klaksvik
# Processing Record 9 of Set 1 | victoria
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | dali
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | camacha
# Processing Record 18 of Set 1 | aklavik
# Processing Record 19 of Set 1 | airai
# Processing Record 20 of Set 1 | pangnirtung
# Processing Record 21 of Set 1 | mendoza
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | manbij
# Processing Record 24 of Set 1 | shenzhen
# Processing Record 25 of Set 1 | rawson
# Processing Record 26 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | fort nelson
# Processing Record 31 of Set 1 | jos
# Processing Record 32 of Set 1 | de aar
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | kudahuvadhoo
# Processing Record 37 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 1 | te anau
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | basco
# Processing Record 41 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 42 of Set 1 | lavrentiya
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | visnes
# Processing Record 45 of Set 1 | vanavara
# Processing Record 46 of Set 1 | havre-saint-pierre
# Processing Record 47 of Set 1 | banda aceh
# Processing Record 48 of Set 1 | buraydah
# Processing Record 49 of Set 1 | le port
# Processing Record 50 of Set 1 | coahuayana
# Processing Record 1 of Set 2 | kruisfontein
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | pisco
# Processing Record 4 of Set 2 | tasiilaq
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | natitingou
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | ucluelet
# Processing Record 10 of Set 2 | kaitangata
# Processing Record 11 of Set 2 | manzil salim
# Processing Record 12 of Set 2 | leningradskiy
# Processing Record 13 of Set 2 | salalah
# Processing Record 14 of Set 2 | tres arroyos
# Processing Record 15 of Set 2 | andenes
# Processing Record 16 of Set 2 | chuy
# Processing Record 17 of Set 2 | colares
# Processing Record 18 of Set 2 | komsomolsk
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | alto paraguai
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | vao
# Processing Record 26 of Set 2 | mar del plata
# Processing Record 27 of Set 2 | vaini
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | santa marta
# Processing Record 30 of Set 2 | port lincoln
# Processing Record 31 of Set 2 | nabire
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | wanning
# Processing Record 34 of Set 2 | port-cartier
# Processing Record 35 of Set 2 | les cayes
# Processing Record 36 of Set 2 | dover
# Processing Record 37 of Set 2 | anadyr
# Processing Record 38 of Set 2 | komsomolskiy
# Processing Record 39 of Set 2 | husavik
# Processing Record 40 of Set 2 | whitehorse
# Processing Record 41 of Set 2 | mathathane
# Processing Record 42 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 2 | cherskiy
# Processing Record 44 of Set 2 | kolyshley
# Processing Record 45 of Set 2 | grindavik
# Processing Record 46 of Set 2 | caravelas
# Processing Record 47 of Set 2 | mount gambier
# Processing Record 48 of Set 2 | lagoa
# Processing Record 49 of Set 2 | saldanha
# Processing Record 50 of Set 2 | tabou
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | glasgow
# Processing Record 5 of Set 3 | kerteh
# City not found. Skipping...
# Processing Record 6 of Set 3 | saint-georges
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | nuuk
# Processing Record 9 of Set 3 | tual
# Processing Record 10 of Set 3 | mosetse
# Processing Record 11 of Set 3 | porto novo
# Processing Record 12 of Set 3 | bud
# Processing Record 13 of Set 3 | garowe
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 3 | nanortalik
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | bafra
# Processing Record 19 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 3 | dakar
# Processing Record 21 of Set 3 | tessalit
# Processing Record 22 of Set 3 | san cristobal
# Processing Record 23 of Set 3 | rocky mountain house
# Processing Record 24 of Set 3 | port alfred
# Processing Record 25 of Set 3 | nara
# Processing Record 26 of Set 3 | carnarvon
# Processing Record 27 of Set 3 | padang
# Processing Record 28 of Set 3 | turka
# Processing Record 29 of Set 3 | porto torres
# Processing Record 30 of Set 3 | atasu
# Processing Record 31 of Set 3 | byron bay
# Processing Record 32 of Set 3 | vung tau
# Processing Record 33 of Set 3 | kavieng
# Processing Record 34 of Set 3 | lovozero
# Processing Record 35 of Set 3 | guilin
# Processing Record 36 of Set 3 | maningrida
# Processing Record 37 of Set 3 | paamiut
# Processing Record 38 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 39 of Set 3 | kayerkan
# Processing Record 40 of Set 3 | bambous virieux
# Processing Record 41 of Set 3 | sao filipe
# Processing Record 42 of Set 3 | tilichiki
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | college
# Processing Record 45 of Set 3 | soyo
# Processing Record 46 of Set 3 | daru
# Processing Record 47 of Set 3 | miranda
# Processing Record 48 of Set 3 | xai-xai
# Processing Record 49 of Set 3 | caxito
# Processing Record 50 of Set 3 | boende
# Processing Record 1 of Set 4 | sarangani
# Processing Record 2 of Set 4 | vestmanna
# Processing Record 3 of Set 4 | goderich
# Processing Record 4 of Set 4 | kaeo
# Processing Record 5 of Set 4 | nacala
# Processing Record 6 of Set 4 | sumkino
# Processing Record 7 of Set 4 | bintulu
# Processing Record 8 of Set 4 | nizhniy odes
# Processing Record 9 of Set 4 | balimo
# City not found. Skipping...
# Processing Record 10 of Set 4 | sioux lookout
# Processing Record 11 of Set 4 | port hawkesbury
# Processing Record 12 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | sitka
# Processing Record 14 of Set 4 | dunedin
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | nikolskoye
# Processing Record 18 of Set 4 | srednekolymsk
# Processing Record 19 of Set 4 | chapais
# Processing Record 20 of Set 4 | brewster
# Processing Record 21 of Set 4 | balagansk
# Processing Record 22 of Set 4 | yellowknife
# Processing Record 23 of Set 4 | luce
# Processing Record 24 of Set 4 | cape town
# Processing Record 25 of Set 4 | monrovia
# Processing Record 26 of Set 4 | terni
# Processing Record 27 of Set 4 | lompoc
# Processing Record 28 of Set 4 | alamos
# Processing Record 29 of Set 4 | sobolevo
# Processing Record 30 of Set 4 | linhares
# Processing Record 31 of Set 4 | avera
# Processing Record 32 of Set 4 | touros
# Processing Record 33 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 4 | fairbanks
# Processing Record 35 of Set 4 | olafsvik
# Processing Record 36 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 4 | xining
# Processing Record 38 of Set 4 | khatanga
# Processing Record 39 of Set 4 | kloulklubed
# Processing Record 40 of Set 4 | zuwarah
# Processing Record 41 of Set 4 | salumbar
# Processing Record 42 of Set 4 | isangel
# Processing Record 43 of Set 4 | severo-kurilsk
# Processing Record 44 of Set 4 | bahia blanca
# Processing Record 45 of Set 4 | aksu
# Processing Record 46 of Set 4 | divnogorsk
# Processing Record 47 of Set 4 | nome
# Processing Record 48 of Set 4 | moosomin
# Processing Record 49 of Set 4 | provideniya
# Processing Record 50 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 5 | port blair
# Processing Record 2 of Set 5 | bitkine
# Processing Record 3 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 5 | axim
# Processing Record 5 of Set 5 | warrnambool
# Processing Record 6 of Set 5 | namatanai
# Processing Record 7 of Set 5 | forrest city
# Processing Record 8 of Set 5 | qaanaaq
# Processing Record 9 of Set 5 | port hardy
# Processing Record 10 of Set 5 | shellbrook
# Processing Record 11 of Set 5 | kampot
# Processing Record 12 of Set 5 | los llanos de aridane
# Processing Record 13 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 5 | saint-francois
# Processing Record 16 of Set 5 | maceio
# Processing Record 17 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 5 | beyneu
# Processing Record 19 of Set 5 | altamira
# Processing Record 20 of Set 5 | collie
# Processing Record 21 of Set 5 | hof
# Processing Record 22 of Set 5 | barmer
# Processing Record 23 of Set 5 | mehamn
# Processing Record 24 of Set 5 | ballina
# Processing Record 25 of Set 5 | menongue
# Processing Record 26 of Set 5 | pacific grove
# Processing Record 27 of Set 5 | rudnogorsk
# Processing Record 28 of Set 5 | jiwani
# Processing Record 29 of Set 5 | alexandria
# Processing Record 30 of Set 5 | melivoia
# Processing Record 31 of Set 5 | egvekinot
# Processing Record 32 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | road town
# Processing Record 34 of Set 5 | valdivia
# Processing Record 35 of Set 5 | rocha
# Processing Record 36 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 5 | kletskaya
# Processing Record 38 of Set 5 | bubaque
# Processing Record 39 of Set 5 | nouadhibou
# Processing Record 40 of Set 5 | tazovskiy
# Processing Record 41 of Set 5 | vila velha
# Processing Record 42 of Set 5 | east london
# Processing Record 43 of Set 5 | yerbogachen
# Processing Record 44 of Set 5 | azrow
# City not found. Skipping...
# Processing Record 45 of Set 5 | kemri
# Processing Record 46 of Set 5 | dutlwe
# Processing Record 47 of Set 5 | makakilo city
# Processing Record 48 of Set 5 | bac lieu
# Processing Record 49 of Set 5 | mae chan
# Processing Record 50 of Set 5 | faya
# Processing Record 1 of Set 6 | pemangkat
# Processing Record 2 of Set 6 | saint-pierre
# Processing Record 3 of Set 6 | chokurdakh
# Processing Record 4 of Set 6 | kurchum
# Processing Record 5 of Set 6 | olutanga
# Processing Record 6 of Set 6 | ibirama
# Processing Record 7 of Set 6 | north platte
# Processing Record 8 of Set 6 | omaruru
# Processing Record 9 of Set 6 | cayenne
# Processing Record 10 of Set 6 | misratah
# Processing Record 11 of Set 6 | marystown
# Processing Record 12 of Set 6 | lardos
# Processing Record 13 of Set 6 | laguna
# Processing Record 14 of Set 6 | constitucion
# Processing Record 15 of Set 6 | tsagan aman
# Processing Record 16 of Set 6 | dikson
# Processing Record 17 of Set 6 | sao domingos
# Processing Record 18 of Set 6 | kemijarvi
# Processing Record 19 of Set 6 | brae
# Processing Record 20 of Set 6 | umm lajj
# Processing Record 21 of Set 6 | clyde river
# Processing Record 22 of Set 6 | vardo
# Processing Record 23 of Set 6 | talnakh
# Processing Record 24 of Set 6 | ponta do sol
# Processing Record 25 of Set 6 | krasnousolskiy
# City not found. Skipping...
# Processing Record 26 of Set 6 | quthing
# Processing Record 27 of Set 6 | yulara
# Processing Record 28 of Set 6 | port elizabeth
# Processing Record 29 of Set 6 | codrington
# Processing Record 30 of Set 6 | tuatapere
# Processing Record 31 of Set 6 | ilulissat
# Processing Record 32 of Set 6 | tamiahua
# Processing Record 33 of Set 6 | hofn
# Processing Record 34 of Set 6 | abha
# Processing Record 35 of Set 6 | zyryanka
# Processing Record 36 of Set 6 | bayir
# Processing Record 37 of Set 6 | doha
# Processing Record 38 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 39 of Set 6 | plettenberg bay
# Processing Record 40 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 6 | synya
# Processing Record 42 of Set 6 | takoradi
# Processing Record 43 of Set 6 | carberry
# Processing Record 44 of Set 6 | knysna
# Processing Record 45 of Set 6 | mao
# Processing Record 46 of Set 6 | peterhead
# Processing Record 47 of Set 6 | gadwal
# Processing Record 48 of Set 6 | tansen
# Processing Record 49 of Set 6 | bone
# Processing Record 50 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 1 of Set 7 | hambantota
# Processing Record 2 of Set 7 | santiago del estero
# Processing Record 3 of Set 7 | lucea
# Processing Record 4 of Set 7 | dzilam gonzalez
# Processing Record 5 of Set 7 | ust-ilimsk
# Processing Record 6 of Set 7 | juneau
# Processing Record 7 of Set 7 | sechura
# Processing Record 8 of Set 7 | bua yai
# Processing Record 9 of Set 7 | trelew
# Processing Record 10 of Set 7 | cockburn town
# Processing Record 11 of Set 7 | santa cruz cabralia
# Processing Record 12 of Set 7 | shelburne
# Processing Record 13 of Set 7 | sterling
# Processing Record 14 of Set 7 | tadine
# Processing Record 15 of Set 7 | saint george
# Processing Record 16 of Set 7 | ghanzi
# Processing Record 17 of Set 7 | comodoro rivadavia
# Processing Record 18 of Set 7 | pareora
# Processing Record 19 of Set 7 | saint-philippe
# Processing Record 20 of Set 7 | mana
# Processing Record 21 of Set 7 | ankang
# Processing Record 22 of Set 7 | saint anthony
# Processing Record 23 of Set 7 | san patricio
# Processing Record 24 of Set 7 | makokou
# Processing Record 25 of Set 7 | eureka
# Processing Record 26 of Set 7 | ukiah
# Processing Record 27 of Set 7 | gat
# Processing Record 28 of Set 7 | mackay
# Processing Record 29 of Set 7 | bathsheba
# Processing Record 30 of Set 7 | esperance
# Processing Record 31 of Set 7 | kizukuri
# Processing Record 32 of Set 7 | mount pleasant
# Processing Record 33 of Set 7 | bairiki
# Processing Record 34 of Set 7 | teya
# Processing Record 35 of Set 7 | nishihara
# Processing Record 36 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 7 | terenos
# Processing Record 38 of Set 7 | cap malheureux
# Processing Record 39 of Set 7 | port keats
# Processing Record 40 of Set 7 | marawi
# Processing Record 41 of Set 7 | souillac
# Processing Record 42 of Set 7 | sao borja
# Processing Record 43 of Set 7 | wainwright
# Processing Record 44 of Set 7 | barra
# Processing Record 45 of Set 7 | lokachi
# Processing Record 46 of Set 7 | presidencia roque saenz pena
# Processing Record 47 of Set 7 | gaogou
# Processing Record 48 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 49 of Set 7 | coquimbo
# Processing Record 50 of Set 7 | alihe
# Processing Record 1 of Set 8 | grand gaube
# Processing Record 2 of Set 8 | fortuna
# Processing Record 3 of Set 8 | terralba
# Processing Record 4 of Set 8 | merke
# Processing Record 5 of Set 8 | maragogi
# Processing Record 6 of Set 8 | itarema
# Processing Record 7 of Set 8 | porto tolle
# Processing Record 8 of Set 8 | najran
# Processing Record 9 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 8 | mayo
# Processing Record 11 of Set 8 | keshan
# City not found. Skipping...
# Processing Record 12 of Set 8 | rio gallegos
# Processing Record 13 of Set 8 | talaya
# Processing Record 14 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 8 | narsaq
# Processing Record 16 of Set 8 | itaiba
# Processing Record 17 of Set 8 | katsuura
# Processing Record 18 of Set 8 | ginda
# Processing Record 19 of Set 8 | batagay-alyta
# Processing Record 20 of Set 8 | caconda
# Processing Record 21 of Set 8 | beringovskiy
# Processing Record 22 of Set 8 | vavuniya
# Processing Record 23 of Set 8 | durres
# Processing Record 24 of Set 8 | assare
# Processing Record 25 of Set 8 | aswan
# Processing Record 26 of Set 8 | korla
# Processing Record 27 of Set 8 | baruun-urt
# Processing Record 28 of Set 8 | lira
# Processing Record 29 of Set 8 | de-kastri
# Processing Record 30 of Set 8 | aripuana
# Processing Record 31 of Set 8 | hyeres
# Processing Record 32 of Set 8 | owando
# Processing Record 33 of Set 8 | cururupu
# Processing Record 34 of Set 8 | norman wells
# Processing Record 35 of Set 8 | yazoo city
# Processing Record 36 of Set 8 | west wendover
# Processing Record 37 of Set 8 | anloga
# Processing Record 38 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 8 | hobe sound
# Processing Record 40 of Set 8 | sangerhausen
# Processing Record 41 of Set 8 | nouakchott
# Processing Record 42 of Set 8 | bardiyah
# Processing Record 43 of Set 8 | redlands
# Processing Record 44 of Set 8 | grand forks
# Processing Record 45 of Set 8 | ranau
# Processing Record 46 of Set 8 | saint-joseph
# Processing Record 47 of Set 8 | shahr-e kord
# Processing Record 48 of Set 8 | japura
# Processing Record 49 of Set 8 | ajaccio
# Processing Record 50 of Set 8 | colonia
# Processing Record 1 of Set 9 | chicama
# Processing Record 2 of Set 9 | torquay
# Processing Record 3 of Set 9 | salmas
# Processing Record 4 of Set 9 | bengkulu
# Processing Record 5 of Set 9 | kuliyapitiya
# Processing Record 6 of Set 9 | qasigiannguit
# Processing Record 7 of Set 9 | la ronge
# Processing Record 8 of Set 9 | moengo
# Processing Record 9 of Set 9 | longyearbyen
# Processing Record 10 of Set 9 | sakakah
# Processing Record 11 of Set 9 | bilibino
# Processing Record 12 of Set 9 | vitre
# Processing Record 13 of Set 9 | sonaguera
# Processing Record 14 of Set 9 | aktash
# Processing Record 15 of Set 9 | segou
# Processing Record 16 of Set 9 | yar-sale
# Processing Record 17 of Set 9 | luwuk
# Processing Record 18 of Set 9 | kisangani
# Processing Record 19 of Set 9 | karratha
# Processing Record 20 of Set 9 | beloha
# Processing Record 21 of Set 9 | el tigre
# Processing Record 22 of Set 9 | muyezerskiy
# Processing Record 23 of Set 9 | qinzhou
# Processing Record 24 of Set 9 | belaya gora
# Processing Record 25 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 26 of Set 9 | labuhan
# Processing Record 27 of Set 9 | san juan
# Processing Record 28 of Set 9 | teguldet
# Processing Record 29 of Set 9 | angra
# City not found. Skipping...
# Processing Record 30 of Set 9 | rosarito
# Processing Record 31 of Set 9 | ulladulla
# Processing Record 32 of Set 9 | san quintin
# Processing Record 33 of Set 9 | burica
# City not found. Skipping...
# Processing Record 34 of Set 9 | mossendjo
# Processing Record 35 of Set 9 | mount isa
# Processing Record 36 of Set 9 | tarija
# Processing Record 37 of Set 9 | cacequi
# Processing Record 38 of Set 9 | maneadero
# Processing Record 39 of Set 9 | boca do acre
# Processing Record 40 of Set 9 | urucara
# Processing Record 41 of Set 9 | sao raimundo das mangabeiras
# Processing Record 42 of Set 9 | banjar
# Processing Record 43 of Set 9 | kiama
# Processing Record 44 of Set 9 | evenskjaer
# City not found. Skipping...
# Processing Record 45 of Set 9 | koumac
# Processing Record 46 of Set 9 | wattwil
# Processing Record 47 of Set 9 | orkney
# Processing Record 48 of Set 9 | manoel urbano
# Processing Record 49 of Set 9 | geraldton
# Processing Record 50 of Set 9 | oranjestad
# Processing Record 1 of Set 10 | tiarei
# Processing Record 2 of Set 10 | morden
# Processing Record 3 of Set 10 | irbit
# Processing Record 4 of Set 10 | nikolayevsk-na-amure
# Processing Record 5 of Set 10 | oktyabrskoye
# Processing Record 6 of Set 10 | nicoya
# Processing Record 7 of Set 10 | christchurch
# Processing Record 8 of Set 10 | trincomalee
# Processing Record 9 of Set 10 | cidreira
# Processing Record 10 of Set 10 | tuy hoa
# Processing Record 11 of Set 10 | varhaug
# Processing Record 12 of Set 10 | amberley
# Processing Record 13 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 10 | porto de moz
# Processing Record 15 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 10 | oyama
# Processing Record 17 of Set 10 | valera
# Processing Record 18 of Set 10 | stokmarknes
# Processing Record 19 of Set 10 | kodiak
# Processing Record 20 of Set 10 | villa corzo
# Processing Record 21 of Set 10 | sayyan
# Processing Record 22 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 10 | jalu
# Processing Record 24 of Set 10 | kieta
# Processing Record 25 of Set 10 | apodi
# Processing Record 26 of Set 10 | sao joao da barra
# Processing Record 27 of Set 10 | te karaka
# Processing Record 28 of Set 10 | chishtian mandi
# Processing Record 29 of Set 10 | sikasso
# Processing Record 30 of Set 10 | bonthe
# Processing Record 31 of Set 10 | svetlogorsk
# Processing Record 32 of Set 10 | umm kaddadah
# Processing Record 33 of Set 10 | teberda
# Processing Record 34 of Set 10 | bording
# Processing Record 35 of Set 10 | paita
# Processing Record 36 of Set 10 | la plata
# Processing Record 37 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 10 | bichura
# Processing Record 39 of Set 10 | kovdor
# Processing Record 40 of Set 10 | progreso
# Processing Record 41 of Set 10 | sigli
# Processing Record 42 of Set 10 | hasaki
# Processing Record 43 of Set 10 | riviere-au-renard
# Processing Record 44 of Set 10 | pierre
# Processing Record 45 of Set 10 | robertsport
# Processing Record 46 of Set 10 | funadhoo
# Processing Record 47 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 10 | portland
# Processing Record 50 of Set 10 | archidona
# Processing Record 1 of Set 11 | sorong
# Processing Record 2 of Set 11 | burdur
# Processing Record 3 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 11 | korampallam
# Processing Record 5 of Set 11 | kahului
# Processing Record 6 of Set 11 | reconquista
# Processing Record 7 of Set 11 | lakes entrance
# Processing Record 8 of Set 11 | aloleng
# Processing Record 9 of Set 11 | aller
# Processing Record 10 of Set 11 | kintinku
# Processing Record 11 of Set 11 | kenai
# Processing Record 12 of Set 11 | chipata
# Processing Record 13 of Set 11 | zhangye
# Processing Record 14 of Set 11 | sawtell
# Processing Record 15 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 11 | changji
# Processing Record 17 of Set 11 | ketchikan
# Processing Record 18 of Set 11 | coria
# Processing Record 19 of Set 11 | escanaba
# Processing Record 20 of Set 11 | ancud
# Processing Record 21 of Set 11 | acapulco
# Processing Record 22 of Set 11 | defiance
# Processing Record 23 of Set 11 | vila franca do campo
# Processing Record 24 of Set 11 | namibe
# Processing Record 25 of Set 11 | shambu
# Processing Record 26 of Set 11 | akim swedru
# Processing Record 27 of Set 11 | erice
# Processing Record 28 of Set 11 | rokytne
# Processing Record 29 of Set 11 | bonaventure
# Processing Record 30 of Set 11 | pangai
# Processing Record 31 of Set 11 | mezhdurechensk
# Processing Record 32 of Set 11 | da lat
# Processing Record 33 of Set 11 | port hedland
# Processing Record 34 of Set 11 | sistranda
# Processing Record 35 of Set 11 | barabai
# Processing Record 36 of Set 11 | yaan
# Processing Record 37 of Set 11 | khandbari
# Processing Record 38 of Set 11 | berlevag
# Processing Record 39 of Set 11 | murgab
# Processing Record 40 of Set 11 | puerto escondido
# Processing Record 41 of Set 11 | sumbe
# Processing Record 42 of Set 11 | robstown
# Processing Record 43 of Set 11 | kinablangan
# Processing Record 44 of Set 11 | anahuac
# Processing Record 45 of Set 11 | boffa
# Processing Record 46 of Set 11 | tatawin
# Processing Record 47 of Set 11 | griffith
# Processing Record 48 of Set 11 | slave lake
# Processing Record 49 of Set 11 | omboue
# Processing Record 50 of Set 11 | inhambane
# Processing Record 1 of Set 12 | lithakia
# Processing Record 2 of Set 12 | stekolnyy
# City not found. Skipping...
# Processing Record 3 of Set 12 | alvik
# Processing Record 4 of Set 12 | glace bay
# Processing Record 5 of Set 12 | dongli
# Processing Record 6 of Set 12 | victor harbor
# Processing Record 7 of Set 12 | kulhudhuffushi
# Processing Record 8 of Set 12 | soto la marina
# Processing Record 9 of Set 12 | adeje
# Processing Record 10 of Set 12 | da nang
# Processing Record 11 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 12 | bogalusa
# Processing Record 13 of Set 12 | molochnoye
# Processing Record 14 of Set 12 | tombouctou
# Processing Record 15 of Set 12 | san ignacio
# Processing Record 16 of Set 12 | ylivieska
# Processing Record 17 of Set 12 | tomatlan
# Processing Record 18 of Set 12 | alta floresta
# Processing Record 19 of Set 12 | leninsk
# Processing Record 20 of Set 12 | muros
# Processing Record 21 of Set 12 | tambura
# Processing Record 22 of Set 12 | santa fe
# Processing Record 23 of Set 12 | san luis
# Processing Record 24 of Set 12 | iquique
# Processing Record 25 of Set 12 | tsabong
# Processing Record 26 of Set 12 | lufilufi
# Processing Record 27 of Set 12 | hit
# Processing Record 28 of Set 12 | matagami
# Processing Record 29 of Set 12 | kolyvan
# Processing Record 30 of Set 12 | terrace
# Processing Record 31 of Set 12 | krasnoselkup
# Processing Record 32 of Set 12 | huntington
# Processing Record 33 of Set 12 | amga
# Processing Record 34 of Set 12 | puerto quijarro
# Processing Record 35 of Set 12 | camopi
# Processing Record 36 of Set 12 | palmer
# Processing Record 37 of Set 12 | biak
# Processing Record 38 of Set 12 | marrakesh
# Processing Record 39 of Set 12 | tommot
# Processing Record 40 of Set 12 | alyangula
# Processing Record 41 of Set 12 | capinzal
# Processing Record 42 of Set 12 | valle de allende
# Processing Record 43 of Set 12 | inuvik
# Processing Record 44 of Set 12 | listvyanka
# Processing Record 45 of Set 12 | talesh
# City not found. Skipping...
# Processing Record 46 of Set 12 | larap
# Processing Record 47 of Set 12 | kidal
# Processing Record 48 of Set 12 | cerritos
# Processing Record 49 of Set 12 | solnechnyy
# Processing Record 50 of Set 12 | san jose
# Processing Record 1 of Set 13 | pilar
# Processing Record 2 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 13 | muncar
# Processing Record 4 of Set 13 | lasa
# Processing Record 5 of Set 13 | rio grande
# Processing Record 6 of Set 13 | drumheller
# Processing Record 7 of Set 13 | bismarck
# Processing Record 8 of Set 13 | susanville
# Processing Record 9 of Set 13 | barsovo
# Processing Record 10 of Set 13 | ahuimanu
# Processing Record 11 of Set 13 | abu samrah
# Processing Record 12 of Set 13 | puerto baquerizo moreno
# Processing Record 13 of Set 13 | jibuti
# Processing Record 14 of Set 13 | pitimbu
# Processing Record 15 of Set 13 | poum
# Processing Record 16 of Set 13 | eganville
# Processing Record 17 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 13 | nantucket
# Processing Record 19 of Set 13 | nevelsk
# Processing Record 20 of Set 13 | sitrah
# Processing Record 21 of Set 13 | lodhikheda
# Processing Record 22 of Set 13 | acari
# Processing Record 23 of Set 13 | buala
# Processing Record 24 of Set 13 | cairns
# Processing Record 25 of Set 13 | dingle
# Processing Record 26 of Set 13 | maraba
# Processing Record 27 of Set 13 | campos altos
# Processing Record 28 of Set 13 | raurkela
# City not found. Skipping...
# Processing Record 29 of Set 13 | boa vista
# Processing Record 30 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 13 | mareeba
# Processing Record 32 of Set 13 | shitanjing
# Processing Record 33 of Set 13 | diamantina
# Processing Record 34 of Set 13 | adrar
# Processing Record 35 of Set 13 | broome
# Processing Record 36 of Set 13 | pandanon
# City not found. Skipping...
# Processing Record 37 of Set 13 | lockhart
# Processing Record 38 of Set 13 | kerman
# Processing Record 39 of Set 13 | manjacaze
# Processing Record 40 of Set 13 | comarapa
# Processing Record 41 of Set 13 | baiao
# Processing Record 42 of Set 13 | butembo
# Processing Record 43 of Set 13 | asuncion nochixtlan
# Processing Record 44 of Set 13 | pundaguitan
# Processing Record 45 of Set 13 | constantine
# Processing Record 46 of Set 13 | bucerias
# Processing Record 47 of Set 13 | sept-iles
# Processing Record 48 of Set 13 | terpsithea
# Processing Record 49 of Set 13 | landerneau
# Processing Record 50 of Set 13 | olinda
# Processing Record 1 of Set 14 | roela
# Processing Record 2 of Set 14 | sol-iletsk
# Processing Record 3 of Set 14 | shieli
# Processing Record 4 of Set 14 | iqaluit
# Processing Record 5 of Set 14 | asau
# Processing Record 6 of Set 14 | raudeberg
# Processing Record 7 of Set 14 | havre
# Processing Record 8 of Set 14 | andselv
# City not found. Skipping...
# Processing Record 9 of Set 14 | gigmoto
# Processing Record 10 of Set 14 | rabo de peixe
# Processing Record 11 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 14 | hanting
# Processing Record 13 of Set 14 | garden city
# Processing Record 14 of Set 14 | batemans bay
# Processing Record 15 of Set 14 | pimenta bueno
# Processing Record 16 of Set 14 | kirillov
# Processing Record 17 of Set 14 | dickinson
# Processing Record 18 of Set 14 | henties bay
# Processing Record 19 of Set 14 | gambela
# Processing Record 20 of Set 14 | ichalkaranji
# Processing Record 21 of Set 14 | luderitz
# Processing Record 22 of Set 14 | batagay
# Processing Record 23 of Set 14 | shache
# Processing Record 24 of Set 14 | bang saphan
# Processing Record 25 of Set 14 | astoria
# Processing Record 26 of Set 14 | kanniyakumari
# Processing Record 27 of Set 14 | champerico
# Processing Record 28 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 14 | badaojiang
# City not found. Skipping...
# Processing Record 30 of Set 14 | nova olimpia
# Processing Record 31 of Set 14 | killybegs
# Processing Record 32 of Set 14 | pabna
# Processing Record 33 of Set 14 | deming
# Processing Record 34 of Set 14 | san pedro buenavista
# Processing Record 35 of Set 14 | degollado
# Processing Record 36 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 37 of Set 14 | dhidhdhoo
# Processing Record 38 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing Record 39 of Set 14 | ostrovnoy
# Processing Record 40 of Set 14 | okha
# Processing Record 41 of Set 14 | marfino
# Processing Record 42 of Set 14 | nieuw amsterdam
# Processing Record 43 of Set 14 | kousseri
# Processing Record 44 of Set 14 | shangzhi
# Processing Record 45 of Set 14 | cap-aux-meules
# Processing Record 46 of Set 14 | kargasok
# Processing Record 47 of Set 14 | qingan
# City not found. Skipping...
# Processing Record 48 of Set 14 | homer
# Processing Record 49 of Set 14 | aykino
# Processing Record 50 of Set 14 | matara
# Processing Record 1 of Set 15 | katobu
# Processing Record 2 of Set 15 | lincoln
# Processing Record 3 of Set 15 | bandarbeyla
# Processing Record 4 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 5 of Set 15 | zhigansk
# Processing Record 6 of Set 15 | praia da vitoria
# Processing Record 7 of Set 15 | zhigalovo
# Processing Record 8 of Set 15 | along
# Processing Record 9 of Set 15 | elizabeth city
# Processing Record 10 of Set 15 | vostok
# Processing Record 11 of Set 15 | pangody
# Processing Record 12 of Set 15 | tempio pausania
# Processing Record 13 of Set 15 | kabo
# Processing Record 14 of Set 15 | sorland
# Processing Record 15 of Set 15 | yaring
# Processing Record 16 of Set 15 | lake havasu city
# Processing Record 17 of Set 15 | cuiluan
# Processing Record 18 of Set 15 | auki
# Processing Record 19 of Set 15 | mae sai
# Processing Record 20 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 15 | susangerd
# Processing Record 22 of Set 15 | areosa
# Processing Record 23 of Set 15 | godhra
# Processing Record 24 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 15 | gallipoli
# Processing Record 26 of Set 15 | chulman
# Processing Record 27 of Set 15 | oksfjord
# Processing Record 28 of Set 15 | christiana
# Processing Record 29 of Set 15 | guerrero negro
# Processing Record 30 of Set 15 | kungurtug
# Processing Record 31 of Set 15 | wau
# Processing Record 32 of Set 15 | khuzhir
# Processing Record 33 of Set 15 | lata
# Processing Record 34 of Set 15 | tautira
# Processing Record 35 of Set 15 | sokoni
# Processing Record 36 of Set 15 | odweyne
# Processing Record 37 of Set 15 | quang ngai
# Processing Record 38 of Set 15 | ahipara
# Processing Record 39 of Set 15 | olean
# Processing Record 40 of Set 15 | gizo
# Processing Record 41 of Set 15 | urusha
# Processing Record 42 of Set 15 | santa rosa
# Processing Record 43 of Set 15 | baker city
# Processing Record 44 of Set 15 | nyurba
# Processing Record 45 of Set 15 | harper
# Processing Record 46 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 47 of Set 15 | havoysund
# Processing Record 48 of Set 15 | viedma
# Processing Record 49 of Set 15 | jardim
# Processing Record 50 of Set 15 | moundsville
# Processing Record 1 of Set 16 | kalat
# Processing Record 2 of Set 16 | cabedelo
# Processing Record 3 of Set 16 | evanston
# Processing Record 4 of Set 16 | gallup
# Processing Record 5 of Set 16 | fort frances
# Processing Record 6 of Set 16 | vestmannaeyjar
# Processing Record 7 of Set 16 | ulyanovo
# City not found. Skipping...
# Processing Record 8 of Set 16 | nador
# Processing Record 9 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 16 | raisinghnagar
# Processing Record 11 of Set 16 | jutai
# Processing Record 12 of Set 16 | coihaique
# Processing Record 13 of Set 16 | pittsfield
# Processing Record 14 of Set 16 | jalpan
# Processing Record 15 of Set 16 | businga
# Processing Record 16 of Set 16 | samarai
# Processing Record 17 of Set 16 | nemuro
# Processing Record 18 of Set 16 | tigil
# Processing Record 19 of Set 16 | merauke
# Processing Record 20 of Set 16 | bitung
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 704

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cabo San Lucas  22.8909 -109.9124     77.50        44          20
# 1        Lorengau  -2.0226  147.2712     77.47        87         100
# 2          Faanui -16.4833 -151.7500     81.00        73          74
# 3         Rikitea -23.1203 -134.9692     76.75        73          57
# 4           Tiksi  71.6872  128.8694    -12.28        98         100
# 5          Shingu  33.7333  135.9833     39.79        76           6
# 6       Saskylakh  71.9167  114.0833     -7.87        90         100
# 7        Klaksvik  62.2266   -6.5890     34.72        58          54
# 8        Victoria  22.2855  114.1577     60.33        70          24
# 9        Thompson  55.7435  -97.8558      3.36        78         100
#
#    Wind Speed Country Current Description
# 0        0.00      MX          few clouds
# 1        8.10      PG     overcast clouds
# 2       15.05      PF       broken clouds
# 3        2.95      PF          light rain
# 4        9.26      RU     overcast clouds
# 5        6.78      JP           clear sky
# 6       17.25      RU     overcast clouds
# 7       19.35      FO       broken clouds
# 8        8.99      HK          few clouds
# 9        8.05      CA          light snow

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cabo San Lucas      MX  22.8909 -109.9124     77.50        44          20
# 1        Lorengau      PG  -2.0226  147.2712     77.47        87         100
# 2          Faanui      PF -16.4833 -151.7500     81.00        73          74
# 3         Rikitea      PF -23.1203 -134.9692     76.75        73          57
# 4           Tiksi      RU  71.6872  128.8694    -12.28        98         100
# 5          Shingu      JP  33.7333  135.9833     39.79        76           6
# 6       Saskylakh      RU  71.9167  114.0833     -7.87        90         100
# 7        Klaksvik      FO  62.2266   -6.5890     34.72        58          54
# 8        Victoria      HK  22.2855  114.1577     60.33        70          24
# 9        Thompson      CA  55.7435  -97.8558      3.36        78         100
#
#    Wind Speed Current Description
# 0        0.00          few clouds
# 1        8.10     overcast clouds
# 2       15.05       broken clouds
# 3        2.95          light rain
# 4        9.26     overcast clouds
# 5        6.78           clear sky
# 6       17.25     overcast clouds
# 7       19.35       broken clouds
# 8        8.99          few clouds
# 9        8.05          light snow

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
